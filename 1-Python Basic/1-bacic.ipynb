# %%
## Python is case sensitive.

name="Nishit"
Name="Shivam"

print(name)
print(Name)
# Out:
# Nishit
# Shivam

# %%
##Indentation

age = 32
if age>30:
    print(age)
print(age)
# Out:
# 32
# 32

# %%
## Line continuation
## Use (\) to continue a statement to the next line.
total = 1+2+3+4+5+6+7\
+2+2+1
print(total)
# Out:
# 33

# %%
## Multiple statenents in a single line.

x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
age=29
nam="Nihsit"

# %%
type(age)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
## Type Inference
variable=10
print(type(variable))
variable="Nisht"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
## Code example of indentation

if True:
    print("correct indentation")
    if False:
        print("This Out Print")
    print("This will print")
print("Outside the If block")
# Out:
# correct indentation
# This will print
# Outside the If block
